# %%
import pandas as pd
import os

# %%
df = pd.read_csv('core/regulatory_map_fin.csv')
df
# Out:
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 24325             UU_2019_4
# 24326             UU_2019_5
# 24327             UU_2019_7
# 24328             UU_2019_8
# 24329             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 24325            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 24326            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 24327            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 24328            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 24329            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 24325  turtle_files/bn/2019/bn_1235-2019.ttl
# 24326    turtle_files/ln/2019/pp8-2019bt.ttl
# 24327    turtle_files/bn/2019/bn662-2019.ttl
# 24328   turtle_files/bn/2019/bn_567-2019.ttl
# 24329    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 24325            new_1_text_files/ln/2019/uu4-2019bt.txt
# 24326            new_1_text_files/ln/2019/uu5-2019bt.txt
# 24327            new_1_text_files/ln/2019/uu7-2019bt.txt
# 24328            new_1_text_files/ln/2019/uu8-2019bt.txt
# 24329            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 24325           new_parsed_files/ln/2019/uu4-2019bt.json
# 24326           new_parsed_files/ln/2019/uu5-2019bt.json
# 24327           new_parsed_files/ln/2019/uu7-2019bt.json
# 24328           new_parsed_files/ln/2019/uu8-2019bt.json
for root, dirs, _ in os.walk('new_1_text_files'):
    for directory in dirs:
        f1 = os.path.join(root, directory)
        f2 = f1.replace('new_1_text_files', 'new_4_turtle_files', 1)
        if not os.path.exists(f2):
            os.makedirs(f2)
        print(f2)
# Out:
# new_4_turtle_files/perda
# new_4_turtle_files/putusan
# new_4_turtle_files/bn
# new_4_turtle_files/ln
# new_4_turtle_files/lain-lain
# new_4_turtle_files/perda/1994
# new_4_turtle_files/perda/1982
# new_4_turtle_files/perda/1992
# new_4_turtle_files/perda/2015
# new_4_turtle_files/perda/2010
# new_4_turtle_files/perda/2003
# new_4_turtle_files/perda/1979
# new_4_turtle_files/perda/2019
# new_4_turtle_files/perda/2012
# new_4_turtle_files/perda/1998
# new_4_turtle_files/perda/1989
# new_4_turtle_files/perda/1996
# new_4_turtle_files/perda/1976
# new_4_turtle_files/perda/2008
# new_4_turtle_files/perda/2013
# new_4_turtle_files/perda/1984
# new_4_turtle_files/perda/2002
# new_4_turtle_files/perda/1991
# new_4_turtle_files/perda/1995
# new_4_turtle_files/perda/1986
# new_4_turtle_files/perda/1983
# new_4_turtle_files/perda/2006
# new_4_turtle_files/perda/2011
# new_4_turtle_files/perda/2004
# new_4_turtle_files/perda/1977
# new_4_turtle_files/perda/1999
# new_4_turtle_files/perda/2009
# new_4_turtle_files/perda/1985
# new_4_turtle_files/perda/1997
# new_4_turtle_files/perda/1990
# new_4_turtle_files/perda/2014
# new_4_turtle_files/perda/2007
# new_4_turtle_files/perda/2018
# new_4_turtle_files/perda/2000
# new_4_turtle_files/perda/1987
# new_4_turtle_files/perda/1980
# new_4_turtle_files/perda/1993
# new_4_turtle_files/perda/2017
# new_4_turtle_files/perda/1981
# new_4_turtle_files/perda/2001
# new_4_turtle_files/perda/2016
# new_4_turtle_files/perda/2005
# new_4_turtle_files/perda/1988
# new_4_turtle_files/putusan/2015
# new_4_turtle_files/putusan/2010
# new_4_turtle_files/putusan/2003
# new_4_turtle_files/putusan/2012
# new_4_turtle_files/putusan/2008
# new_4_turtle_files/putusan/2013
# new_4_turtle_files/putusan/2002
# new_4_turtle_files/putusan/2006
# new_4_turtle_files/putusan/2011
# new_4_turtle_files/putusan/2004
# new_4_turtle_files/putusan/2009
# new_4_turtle_files/putusan/2014
# new_4_turtle_files/putusan/2007
# new_4_turtle_files/putusan/2000
# new_4_turtle_files/putusan/2005
# new_4_turtle_files/bn/18
# new_4_turtle_files/bn/1463
# new_4_turtle_files/bn/2015
# new_4_turtle_files/bn/2010
# new_4_turtle_files/bn/2019
# new_4_turtle_files/bn/2012
# new_4_turtle_files/bn/1465
# new_4_turtle_files/bn/2008
# new_4_turtle_files/bn/2013
# new_4_turtle_files/bn/438
# new_4_turtle_files/bn/2011
# new_4_turtle_files/bn/2009
# new_4_turtle_files/bn/1970
# new_4_turtle_files/bn/2020
# new_4_turtle_files/bn/2014
# new_4_turtle_files/bn/2007
# new_4_turtle_files/bn/2018
# new_4_turtle_files/lain-lain/1978
# new_4_turtle_files/lain-lain/1957
# new_4_turtle_files/lain-lain/1925
# new_4_turtle_files/lain-lain/1971
# new_4_turtle_files/lain-lain/2012
# new_4_turtle_files/lain-lain/1967
# new_4_turtle_files/lain-lain/1973
# new_4_turtle_files/lain-lain/1998
# new_4_turtle_files/lain-lain/1929
# new_4_turtle_files/lain-lain/1847
# new_4_turtle_files/lain-lain/1989
# new_4_turtle_files/lain-lain/1996
# new_4_turtle_files/lain-lain/1976
# new_4_turtle_files/lain-lain/1927
# new_4_turtle_files/lain-lain/1956
# new_4_turtle_files/lain-lain/2008
# new_4_turtle_files/lain-lain/1950
# new_4_turtle_files/lain-lain/1945
# new_4_turtle_files/lain-lain/2013
# new_4_turtle_files/lain-lain/1984
# new_4_turtle_files/lain-lain/2002
# new_4_turtle_files/lain-lain/1995
# new_4_turtle_files/lain-lain/1986
# new_4_turtle_files/lain-lain/1983
# new_4_turtle_files/lain-lain/1952
# new_4_turtle_files/lain-lain/2006
# new_4_turtle_files/lain-lain/1951
# new_4_turtle_files/lain-lain/2011
# new_4_turtle_files/lain-lain/1965
# new_4_turtle_files/lain-lain/2004
# new_4_turtle_files/lain-lain/1974
# new_4_turtle_files/lain-lain/1977
# new_4_turtle_files/lain-lain/1999
# new_4_turtle_files/lain-lain/2009
# new_4_turtle_files/lain-lain/1953
# new_4_turtle_files/lain-lain/1912
# new_4_turtle_files/lain-lain/1964
# new_4_turtle_files/lain-lain/1941
# new_4_turtle_files/lain-lain/1968
# new_4_turtle_files/lain-lain/1985
# new_4_turtle_files/lain-lain/1937
# new_4_turtle_files/lain-lain/1949
# new_4_turtle_files/lain-lain/1997
# new_4_turtle_files/lain-lain/1955
# new_4_turtle_files/lain-lain/1969
# new_4_turtle_files/lain-lain/1990
# new_4_turtle_files/lain-lain/2014
# new_4_turtle_files/lain-lain/2007
# new_4_turtle_files/lain-lain/1933
# new_4_turtle_files/lain-lain/2000
# new_4_turtle_files/lain-lain/1915
# new_4_turtle_files/lain-lain/1958
# new_4_turtle_files/lain-lain/1987
# new_4_turtle_files/lain-lain/1980
# new_4_turtle_files/lain-lain/1993
# new_4_turtle_files/lain-lain/1981
# new_4_turtle_files/lain-lain/2001
# new_4_turtle_files/lain-lain/2005
# new_4_turtle_files/lain-lain/1988

# %% [markdown]
# ## Surface Information

# %%
import time

from rdflib import Graph

def extract_turtle(regulatory_id, turtle_file_path, text_file_path):
    target_file = text_file_path.replace('new_1_text_files', 'new_2_turtle_files')
    target_file = target_file.replace('txt', 'ttl')
    
    print(f'{regulatory_id} {turtle_file_path} {target_file}')
    
    if os.path.exists(target_file):
        print(f'{target_file} already exists. Skipping...')
        with open('result2.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        return
    
    start = time.time()
    
    try:
        g = Graph()
        g.parse(turtle_file_path, format='ttl')

        query = f"""
        prefix xsd: <http://www.w3.org/2001/XMLSchema#>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        prefix dbo: <http://dbpedia.org/ontology/>
        prefix dct: <http://purl.org/dc/terms/>
        prefix owl: <http://www.w3.org/2002/07/owl#>
        prefix wd: <https://www.wikidata.org/wiki/>
        prefix lexid-s: <https://w3id.org/lex-id/schema/>
        prefix lexid: <https://w3id.org/lex-id/data/>

        construct {{
            # ?z ?p ?o .
            # ?o ?p1 ?o2 .
        }}
        where {{
            {{
                select distinct ?z ?p ?o
                where {{
                    lexid:{regulatory_id} (
                        lexid-s:considers 
                        | dct:description 
                        | dct:description 
                        | lexid-s:name 
                        | lexid-s:hasCreator 
                        | lexid-s:hasDictum 
                        | lexid-s:hasCreator 
                        | lexid-s:hasEnactionDate 
                        | lexid-s:hasEnactionLocation 
                        | lexid-s:hasEnactionOffice 
                        | lexid-s:hasEnactionOfficial 
                        | lexid-s:hasPromulgationDate 
                        | lexid-s:hasPromulgationLocation 
                        | lexid-s:hasPromulgationOffice 
                        | lexid-s:hasPromulgationOfficial 
                        | lexid-s:hasPromulgationPlace 
                        | lexid-s:hasRegulationNumber 
                        | lexid-s:hasRegulationYear 
                        | rdfs:label 
                        | rdf:type
                        | lexid-s:hasLegalBasis 
                        | lexid-s:LegalBasisOf 
                        | lexid-s:hasContent 
                        | lexid-s:isContentOf 
                        | lexid-s:hasPart 
                        | lexid-s:isPartOf 
                    )* ?z .
                    # ?z ?p ?o .
                    FILTER (?p NOT IN (rdf:type
                                        , owl:sameAs
                                        , lexid-s:adds
                                        , lexid-s:hasAdditionContent
                                        , lexid-s:hasAdditionTarget
                                        , lexid-s:deletes
                                        , lexid-s:modifies
                                        , lexid-s:hasModificationContent
                                        , lexid-s:hasModificationTarget
                                        , lexid-s:hasAct
                                        , lexid-s:hasActType
                                        , lexid-s:hasElement
                                        , lexid-s:hasCondition
                                        , lexid-s:hasModality
                                        , lexid-s:hasObject
                                        , lexid-s:hasQualifier
                                        , lexid-s:hasQualifierType
                                        , lexid-s:hasQualifierValue
                                        , lexid-s:hasRule
                                        , lexid-s:hasSubject
                                        , lexid-s:isRuleOf
                                        , lexid-s:refersTo
                                        , lexid-s:amendedBy
                                        , lexid-s:amends
                                        , lexid-s:implementedBy
                                        , lexid-s:implements
                                        , lexid-s:repealedBy
                                        , lexid-s:repeals
                                        , lexid-s:undefined))
                }}
            }}
            OPTIONAL {{
                # ?o ?p1 ?o2 .
                FILTER (?p1 IN (rdf:type) && ?o2 NOT IN (owl:Thing
                                                        , lexid-s:LawAmandment
                                                        , lexid-s:Act
                                                        , lexid-s:AgencyRegulation
                                                        , lexid-s:AmendmentToTheConstitution
                                                        , lexid-s:CityOrdinance
                                                        , lexid-s:Constitution
                                                        , lexid-s:GovernmentRegulation
                                                        , lexid-s:GovernmentRegulationInLieuOfAct
                                                        , lexid-s:GovernorRegulation
                                                        , lexid-s:JointRegulation
                                                        , lexid-s:MayorRegulation
                                                        , lexid-s:MinisterialDecree
                                                        , lexid-s:MinisterialRegulation
                                                        , lexid-s:PeoplesConsultativeAssemblyResolution
                                                        , lexid-s:PresidentialDecree
                                                        , lexid-s:PresidentialRegulation
                                                        , lexid-s:ProvincialOrdinance
                                                        , lexid-s:RegencyOrdinance
                                                        , lexid-s:RegentRegulation
                                                        , lexid-s:LegalDocumentContent
                                                        , lexid-s:RuleExpression))
            }}
        }}
        """

        g.bind('rdf', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#')
        g.bind('lexid-s', 'https://w3id.org/lex-id/schema/')
        g.bind('lexid', 'https://w3id.org/lex-id/data/')
        g.bind('dct', 'http://purl.org/dc/terms/')
        g.bind('xsd', 'http://www.w3.org/2001/XMLSchema#')
        g.bind('rdfs', 'http://www.w3.org/2000/01/rdf-schema#')
        g.bind('dbo', 'http://dbpedia.org/ontology/')
        g.bind('owl', 'http://www.w3.org/2002/07/owl#')
        g.bind('wd', 'https://www.wikidata.org/wiki/')

        results = g.query(query)

        f = open(target_file, 'w')

        prefixes = ['@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .',
                    '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .',
                    '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .',
                    '@prefix dbo: <http://dbpedia.org/ontology/> .',
                    '@prefix dct: <http://purl.org/dc/terms/> .',
                    '@prefix owl: <http://www.w3.org/2002/07/owl#> .',
                    '@prefix wd: <https://www.wikidata.org/wiki/> .',
                    '@prefix lexid-s: <https://w3id.org/lex-id/schema/> .',
                    '@prefix lexid: <https://w3id.org/lex-id/data/> .']

        for prefix in prefixes:
            res = F"{prefix}\n"
            f.write(res)

        f.write('\n')

        for result in results:
            subject = result[0].n3(g.namespace_manager)
            predicate = result[1].n3(g.namespace_manager)
            obj = result[2].n3(g.namespace_manager)
            res = F"{subject} {predicate} {obj} .\n"
            f.write(res)

        f.close()
        with open('result2.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        
    except Exception as e:
        print(e)
        with open('error2.txt', 'a') as f: 
            f.write(f'{regulatory_id} {turtle_file_path}\n')

    end = time.time()
    print(f'{regulatory_id} from {turtle_file_path} to {target_file} execution time {end - start} seconds')

# %% [markdown]
# ## Opening

# %%
import time

from rdflib import Graph

def extract_turtle(regulatory_id, turtle_file_path, text_file_path):
    target_file = text_file_path.replace('new_1_text_files', 'new_3_turtle_files')
    target_file = target_file.replace('txt', 'ttl')
    
    print(f'{regulatory_id} {turtle_file_path} {target_file}')
    
    if os.path.exists(target_file):
        print(f'{target_file} already exists. Skipping...')
        with open('result2.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        return
    
    start = time.time()
    
    try:
        g = Graph()
        g.parse(turtle_file_path, format='ttl')

        query = f"""
        prefix xsd: <http://www.w3.org/2001/XMLSchema#>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        prefix dbo: <http://dbpedia.org/ontology/>
        prefix dct: <http://purl.org/dc/terms/>
        prefix owl: <http://www.w3.org/2002/07/owl#>
        prefix wd: <https://www.wikidata.org/wiki/>
        prefix lexid-s: <https://w3id.org/lex-id/schema/>
        prefix lexid: <https://w3id.org/lex-id/data/>

        construct {{
            # ?z ?p ?o .
            # ?o ?p1 ?o2 .
        }}
        where {{
            {{
                select distinct ?z ?p ?o
                where {{
                    lexid:{regulatory_id} (
                        lexid-s:considers 
                        | dct:description 
                        | lexid-s:name 
                        | lexid-s:hasCreator 
                        | lexid-s:hasDictum 
                        | lexid-s:hasCreator 
                        | lexid-s:hasRegulationNumber 
                        | lexid-s:hasRegulationYear 
                        | rdfs:label 
                        | rdf:type
                        | lexid-s:hasLegalBasis 
                        | lexid-s:LegalBasisOf 
                    )* ?z .
                    # ?z ?p ?o .
                    FILTER (?p NOT IN (rdf:type
                                        , owl:sameAs
                                        , lexid-s:adds
                                        , lexid-s:hasAdditionContent
                                        , lexid-s:hasAdditionTarget
                                        , lexid-s:deletes
                                        , lexid-s:modifies
                                        , lexid-s:hasModificationContent
                                        , lexid-s:hasModificationTarget
                                        , lexid-s:hasAct
                                        , lexid-s:hasActType
                                        , lexid-s:hasElement
                                        , lexid-s:hasCondition
                                        , lexid-s:hasModality
                                        , lexid-s:hasObject
                                        , lexid-s:hasQualifier
                                        , lexid-s:hasQualifierType
                                        , lexid-s:hasQualifierValue
                                        , lexid-s:hasRule
                                        , lexid-s:hasSubject
                                        , lexid-s:isRuleOf
                                        , lexid-s:refersTo
                                        , lexid-s:amendedBy
                                        , lexid-s:amends
                                        , lexid-s:implementedBy
                                        , lexid-s:implements
                                        , lexid-s:repealedBy
                                        , lexid-s:repeals
                                        , lexid-s:undefined
                                        , lexid-s:hasEnactionDate 
                                        , lexid-s:hasEnactionLocation 
                                        , lexid-s:hasEnactionOffice 
                                        , lexid-s:hasEnactionOfficial 
                                        , lexid-s:hasPromulgationDate 
                                        , lexid-s:hasPromulgationLocation 
                                        , lexid-s:hasPromulgationOffice 
                                        , lexid-s:hasPromulgationOfficial 
                                        , lexid-s:hasPromulgationPlace 
                                        , lexid-s:hasContent 
                                        , lexid-s:isContentOf 
                                        , lexid-s:hasPart 
                                        , lexid-s:isPartOf 
                                        ))
                }}
            }}
            OPTIONAL {{
                # ?o ?p1 ?o2 .
                FILTER (?p1 IN (rdf:type) && ?o2 NOT IN (owl:Thing
                                                        , lexid-s:LawAmandment
                                                        , lexid-s:Act
                                                        , lexid-s:AgencyRegulation
                                                        , lexid-s:AmendmentToTheConstitution
                                                        , lexid-s:CityOrdinance
                                                        , lexid-s:Constitution
                                                        , lexid-s:GovernmentRegulation
                                                        , lexid-s:GovernmentRegulationInLieuOfAct
                                                        , lexid-s:GovernorRegulation
                                                        , lexid-s:JointRegulation
                                                        , lexid-s:MayorRegulation
                                                        , lexid-s:MinisterialDecree
                                                        , lexid-s:MinisterialRegulation
                                                        , lexid-s:PeoplesConsultativeAssemblyResolution
                                                        , lexid-s:PresidentialDecree
                                                        , lexid-s:PresidentialRegulation
                                                        , lexid-s:ProvincialOrdinance
                                                        , lexid-s:RegencyOrdinance
                                                        , lexid-s:RegentRegulation
                                                        , lexid-s:LegalDocumentContent
                                                        , lexid-s:RuleExpression))
            }}
        }}
        """

        g.bind('rdf', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#')
        g.bind('lexid-s', 'https://w3id.org/lex-id/schema/')
        g.bind('lexid', 'https://w3id.org/lex-id/data/')
        g.bind('dct', 'http://purl.org/dc/terms/')
        g.bind('xsd', 'http://www.w3.org/2001/XMLSchema#')
        g.bind('rdfs', 'http://www.w3.org/2000/01/rdf-schema#')
        g.bind('dbo', 'http://dbpedia.org/ontology/')
        g.bind('owl', 'http://www.w3.org/2002/07/owl#')
        g.bind('wd', 'https://www.wikidata.org/wiki/')

        results = g.query(query)

        f = open(target_file, 'w')

        prefixes = ['@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .',
                    '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .',
                    '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .',
                    '@prefix dbo: <http://dbpedia.org/ontology/> .',
                    '@prefix dct: <http://purl.org/dc/terms/> .',
                    '@prefix owl: <http://www.w3.org/2002/07/owl#> .',
                    '@prefix wd: <https://www.wikidata.org/wiki/> .',
                    '@prefix lexid-s: <https://w3id.org/lex-id/schema/> .',
                    '@prefix lexid: <https://w3id.org/lex-id/data/> .']

        for prefix in prefixes:
            res = F"{prefix}\n"
            f.write(res)

        f.write('\n')

        for result in results:
            subject = result[0].n3(g.namespace_manager)
            predicate = result[1].n3(g.namespace_manager)
            obj = result[2].n3(g.namespace_manager)
            res = F"{subject} {predicate} {obj} .\n"
            f.write(res)

        f.close()
        with open('result3.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        
    except Exception as e:
        print(e)
        with open('error3.txt', 'a') as f: 
            f.write(f'{regulatory_id} {turtle_file_path}\n')

    end = time.time()
    print(f'{regulatory_id} from {turtle_file_path} to {target_file} execution time {end - start} seconds')

# %% [markdown]
# ## Closing

# %%
import time

from rdflib import Graph

def extract_turtle(regulatory_id, turtle_file_path, text_file_path):
    target_file = text_file_path.replace('new_1_text_files', 'new_4_turtle_files')
    target_file = target_file.replace('txt', 'ttl')
    
    print(f'{regulatory_id} {turtle_file_path} {target_file}')
    
    if os.path.exists(target_file):
        print(f'{target_file} already exists. Skipping...')
        with open('result2.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        return
    
    start = time.time()
    
    try:
        g = Graph()
        g.parse(turtle_file_path, format='ttl')

        query = f"""
        prefix xsd: <http://www.w3.org/2001/XMLSchema#>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        prefix dbo: <http://dbpedia.org/ontology/>
        prefix dct: <http://purl.org/dc/terms/>
        prefix owl: <http://www.w3.org/2002/07/owl#>
        prefix wd: <https://www.wikidata.org/wiki/>
        prefix lexid-s: <https://w3id.org/lex-id/schema/>
        prefix lexid: <https://w3id.org/lex-id/data/>

        construct {{
            # ?z ?p ?o .
            # ?o ?p1 ?o2 .
        }}
        where {{
            {{
                select distinct ?z ?p ?o
                where {{
                    lexid:{regulatory_id} (
                        lexid-s:hasEnactionLocation 
                        | lexid-s:hasEnactionOffice 
                        | lexid-s:hasEnactionOfficial 
                        | lexid-s:hasEnactionDate                         
                        | lexid-s:hasPromulgationDate 
                        | lexid-s:hasPromulgationLocation 
                        | lexid-s:hasPromulgationOffice 
                        | lexid-s:hasPromulgationOfficial 
                        | lexid-s:hasPromulgationPlace 
                    )? ?z .
                    # ?z ?p ?o .
                    FILTER (?p IN (rdfs:label 
                                    , dct:description
                                    , lexid-s:name
                                    , lexid-s:hasEnactionLocation 
                                    , lexid-s:hasEnactionOffice 
                                    , lexid-s:hasEnactionOfficial 
                                    , lexid-s:hasEnactionDate 
                                    , lexid-s:hasPromulgationDate 
                                    , lexid-s:hasPromulgationLocation 
                                    , lexid-s:hasPromulgationOffice 
                                    , lexid-s:hasPromulgationOfficial 
                                    , lexid-s:hasPromulgationPlace
                                    ))
                }}
            }}
            OPTIONAL {{
                # ?o ?p1 ?o2 .
                FILTER (?p1 IN (rdf:type) && ?o2 NOT IN (owl:Thing
                                                        , lexid-s:LawAmandment
                                                        , lexid-s:Act
                                                        , lexid-s:AgencyRegulation
                                                        , lexid-s:AmendmentToTheConstitution
                                                        , lexid-s:CityOrdinance
                                                        , lexid-s:Constitution
                                                        , lexid-s:GovernmentRegulation
                                                        , lexid-s:GovernmentRegulationInLieuOfAct
                                                        , lexid-s:GovernorRegulation
                                                        , lexid-s:JointRegulation
                                                        , lexid-s:MayorRegulation
                                                        , lexid-s:MinisterialDecree
                                                        , lexid-s:MinisterialRegulation
                                                        , lexid-s:PeoplesConsultativeAssemblyResolution
                                                        , lexid-s:PresidentialDecree
                                                        , lexid-s:PresidentialRegulation
                                                        , lexid-s:ProvincialOrdinance
                                                        , lexid-s:RegencyOrdinance
                                                        , lexid-s:RegentRegulation
                                                        , lexid-s:LegalDocumentContent
                                                        , lexid-s:RuleExpression))
            }}
            
            MINUS {{
                lexid:{regulatory_id} ?p ?o .
                FILTER (?p IN (rdfs:label 
                                , dct:description
                                , lexid-s:name))
            }}
        }}
        """

        g.bind('rdf', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#')
        g.bind('lexid-s', 'https://w3id.org/lex-id/schema/')
        g.bind('lexid', 'https://w3id.org/lex-id/data/')
        g.bind('dct', 'http://purl.org/dc/terms/')
        g.bind('xsd', 'http://www.w3.org/2001/XMLSchema#')
        g.bind('rdfs', 'http://www.w3.org/2000/01/rdf-schema#')
        g.bind('dbo', 'http://dbpedia.org/ontology/')
        g.bind('owl', 'http://www.w3.org/2002/07/owl#')
        g.bind('wd', 'https://www.wikidata.org/wiki/')

        results = g.query(query)

        f = open(target_file, 'w')

        prefixes = ['@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .',
                    '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .',
                    '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .',
                    '@prefix dbo: <http://dbpedia.org/ontology/> .',
                    '@prefix dct: <http://purl.org/dc/terms/> .',
                    '@prefix owl: <http://www.w3.org/2002/07/owl#> .',
                    '@prefix wd: <https://www.wikidata.org/wiki/> .',
                    '@prefix lexid-s: <https://w3id.org/lex-id/schema/> .',
                    '@prefix lexid: <https://w3id.org/lex-id/data/> .']

        for prefix in prefixes:
            res = F"{prefix}\n"
            f.write(res)

        f.write('\n')

        for result in results:
            subject = result[0].n3(g.namespace_manager)
            predicate = result[1].n3(g.namespace_manager)
            obj = result[2].n3(g.namespace_manager)
            res = F"{subject} {predicate} {obj} .\n"
            f.write(res)

        f.close()
        with open('result4.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        
    except Exception as e:
        print(e)
        with open('error4.txt', 'a') as f: 
            f.write(f'{regulatory_id} {turtle_file_path}\n')

    end = time.time()
    print(f'{regulatory_id} from {turtle_file_path} to {target_file} execution time {end - start} seconds')

# %% [markdown]
# ## Body

# %%
import time

from rdflib import Graph

def extract_turtle(regulatory_id, turtle_file_path, text_file_path):
    target_file = text_file_path.replace('new_1_text_files', 'new_5_turtle_files')
    target_file = target_file.replace('txt', 'ttl')
    
    print(f'{regulatory_id} {turtle_file_path} {target_file}')
    
    if os.path.exists(target_file):
        print(f'{target_file} already exists. Skipping...')
        with open('result2.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        return
    
    start = time.time()
    
    try:
        g = Graph()
        g.parse(turtle_file_path, format='ttl')

        query = f"""
        prefix xsd: <http://www.w3.org/2001/XMLSchema#>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        prefix dbo: <http://dbpedia.org/ontology/>
        prefix dct: <http://purl.org/dc/terms/>
        prefix owl: <http://www.w3.org/2002/07/owl#>
        prefix wd: <https://www.wikidata.org/wiki/>
        prefix lexid-s: <https://w3id.org/lex-id/schema/>
        prefix lexid: <https://w3id.org/lex-id/data/>

        construct {{
            # ?z ?p ?o .
            # ?o ?p1 ?o2 .
        }}
        where {{
            {{
                select distinct ?z ?p ?o
                where {{
                    lexid:{regulatory_id} (
                        dct:description 
                        | lexid-s:name  
                        | rdfs:label 
                        | rdf:type
                        | lexid-s:hasContent 
                        | lexid-s:isContentOf 
                        | lexid-s:hasPart 
                        | lexid-s:isPartOf
                    )* ?z .
                    # ?z ?p ?o .
                    FILTER (?p NOT IN (rdf:type
                                        , owl:sameAs
                                        , lexid-s:adds
                                        , lexid-s:hasAdditionContent
                                        , lexid-s:hasAdditionTarget
                                        , lexid-s:deletes
                                        , lexid-s:modifies
                                        , lexid-s:hasModificationContent
                                        , lexid-s:hasModificationTarget
                                        , lexid-s:hasAct
                                        , lexid-s:hasActType
                                        , lexid-s:hasElement
                                        , lexid-s:hasCondition
                                        , lexid-s:hasModality
                                        , lexid-s:hasObject
                                        , lexid-s:hasQualifier
                                        , lexid-s:hasQualifierType
                                        , lexid-s:hasQualifierValue
                                        , lexid-s:hasRule
                                        , lexid-s:hasSubject
                                        , lexid-s:isRuleOf
                                        , lexid-s:refersTo
                                        , lexid-s:amendedBy
                                        , lexid-s:amends
                                        , lexid-s:implementedBy
                                        , lexid-s:implements
                                        , lexid-s:repealedBy
                                        , lexid-s:repeals
                                        , lexid-s:undefined
                                        , lexid-s:hasEnactionDate 
                                        , lexid-s:hasEnactionLocation 
                                        , lexid-s:hasEnactionOffice 
                                        , lexid-s:hasEnactionOfficial 
                                        , lexid-s:hasPromulgationDate 
                                        , lexid-s:hasPromulgationLocation 
                                        , lexid-s:hasPromulgationOffice 
                                        , lexid-s:hasPromulgationOfficial 
                                        , lexid-s:hasPromulgationPlace 
                                        , lexid-s:hasCreator 
                                        , lexid-s:hasDictum 
                                        , lexid-s:hasCreator 
                                        , lexid-s:regulationNumber 
                                        , lexid-s:regulationYear
                                        , lexid-s:considers 
                                        , lexid-s:hasLegalBasis 
                                        , lexid-s:LegalBasisOf 
                                        ))
                }}
            }}
            OPTIONAL {{
                # ?o ?p1 ?o2 .
                FILTER (?p1 IN (rdf:type) && ?o2 NOT IN (owl:Thing
                                                        , lexid-s:LawAmandment
                                                        , lexid-s:Act
                                                        , lexid-s:AgencyRegulation
                                                        , lexid-s:AmendmentToTheConstitution
                                                        , lexid-s:CityOrdinance
                                                        , lexid-s:Constitution
                                                        , lexid-s:GovernmentRegulation
                                                        , lexid-s:GovernmentRegulationInLieuOfAct
                                                        , lexid-s:GovernorRegulation
                                                        , lexid-s:JointRegulation
                                                        , lexid-s:MayorRegulation
                                                        , lexid-s:MinisterialDecree
                                                        , lexid-s:MinisterialRegulation
                                                        , lexid-s:PeoplesConsultativeAssemblyResolution
                                                        , lexid-s:PresidentialDecree
                                                        , lexid-s:PresidentialRegulation
                                                        , lexid-s:ProvincialOrdinance
                                                        , lexid-s:RegencyOrdinance
                                                        , lexid-s:RegentRegulation
                                                        , lexid-s:LegalDocument
                                                        , lexid-s:LegalDocumentContent
                                                        , lexid-s:RuleExpression))
            }}
            
            MINUS {{
                lexid:{regulatory_id} ?p ?o .
                FILTER (?p IN (rdfs:label 
                                , dct:description
                                , lexid-s:name
                                , rdf:type))
            }}
        }}
        """

        g.bind('rdf', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#')
        g.bind('lexid-s', 'https://w3id.org/lex-id/schema/')
        g.bind('lexid', 'https://w3id.org/lex-id/data/')
        g.bind('dct', 'http://purl.org/dc/terms/')
        g.bind('xsd', 'http://www.w3.org/2001/XMLSchema#')
        g.bind('rdfs', 'http://www.w3.org/2000/01/rdf-schema#')
        g.bind('dbo', 'http://dbpedia.org/ontology/')
        g.bind('owl', 'http://www.w3.org/2002/07/owl#')
        g.bind('wd', 'https://www.wikidata.org/wiki/')

        results = g.query(query)

        f = open(target_file, 'w')

        prefixes = ['@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .',
                    '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .',
                    '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .',
                    '@prefix dbo: <http://dbpedia.org/ontology/> .',
                    '@prefix dct: <http://purl.org/dc/terms/> .',
                    '@prefix owl: <http://www.w3.org/2002/07/owl#> .',
                    '@prefix wd: <https://www.wikidata.org/wiki/> .',
                    '@prefix lexid-s: <https://w3id.org/lex-id/schema/> .',
                    '@prefix lexid: <https://w3id.org/lex-id/data/> .']

        for prefix in prefixes:
            res = F"{prefix}\n"
            f.write(res)

        f.write('\n')

        for result in results:
            subject = result[0].n3(g.namespace_manager)
            predicate = result[1].n3(g.namespace_manager)
            obj = result[2].n3(g.namespace_manager)
            res = F"{subject} {predicate} {obj} .\n"
            f.write(res)

        f.close()
        with open('result5.txt', 'a') as f: 
            f.write(f'{regulatory_id}\n')
        
    except Exception as e:
        print(e)
        with open('error5.txt', 'a') as f: 
            f.write(f'{regulatory_id} {turtle_file_path}\n')

    end = time.time()
    print(f'{regulatory_id} from {turtle_file_path} to {target_file} execution time {end - start} seconds')
